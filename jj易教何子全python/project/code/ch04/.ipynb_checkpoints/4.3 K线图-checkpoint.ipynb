# %% [markdown]
# ### 4.3.2 案例：绘制英伟达股票K线图

# %% [markdown]
# #### 1.加载和预处理数据

# %%
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt

# 读取CSV文件
file_path = 'data/HistoricalData_NVIDIA.csv'  # 请确保文件路径正确
df = pd.read_csv(file_path)

# 将“Date”列转换为日期格式
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
# 确保日期按升序排列（从最早到最新的日期）
df = df.sort_values(by='Date')
# 将 'Date' 列设置为索引
df.set_index('Date', inplace=True)

# 清洗数据：移除所有的非数字字符（如美元符号 $），并转换为数值类型
df['Low'] = df['Low'].str.replace('$', '').astype(float)
df['High'] = df['High'].str.replace('$', '').astype(float)
df['Open'] = df['Open'].str.replace('$', '').astype(float)
df['Close'] = df['Close/Last'].str.replace('$', '').astype(float)
df # 打印df
# Out:
#            Close/Last     Volume     Open    High      Low   Close
# Date
# 2025-01-21    $140.83  197749000  139.160  141.83  137.090  140.83
# 2025-01-22    $147.07  237651400  144.660  147.79  143.670  147.07
# 2025-01-23    $147.22  155915500  145.050  147.23  143.720  147.22
# 2025-01-24    $142.62  234657600  148.370  148.97  141.880  142.62
# 2025-01-27    $118.42  818830900  124.800  128.40  116.700  118.42
# 2025-01-28    $128.99  579666400  121.810  129.00  116.250  128.99
# 2025-01-29    $123.70  467120600  126.500  126.89  120.050  123.70
# 2025-01-30    $124.65  392925500  123.100  125.00  118.100  124.65
# 2025-01-31    $120.07  390372900  123.780  127.85  119.190  120.07
# 2025-02-03    $116.66  371235700  114.750  118.57  113.010  116.66
# 2025-02-04    $118.65  256550000  116.960  121.20  116.700  118.65
# 2025-02-05    $124.83  263110600  121.760  125.00  120.760  124.83
# 2025-02-06    $128.68  251483600  127.420  128.77  125.210  128.68
# 2025-02-07    $129.84  228186300  129.220  130.37  125.000  129.84
# 2025-02-10    $133.57  216989100  130.090  135.00  129.960  133.57
# 2025-02-11    $132.80  178902400  132.580  134.48  131.020  132.80
# 2025-02-12    $131.14  160278600  130.020  132.24  129.080  131.14
# 2025-02-13    $135.29  197430000  131.555  136.50  131.170  135.29
# 2025-02-14    $138.85  195479600  136.480  139.25  135.500  138.85
# 2025-02-18    $139.40  219176600  141.270  143.44  137.925  139.40

# %% [markdown]
# #### 2. 绘制K线图

# %%
# 绘制K线图
market_colors = mpf.make_marketcolors(up='red', down='green')

my_style = mpf.make_mpf_style(marketcolors=market_colors)
# 绘制K线图
mpf.plot(df, type='candle', 
         volume=True, 
         show_nontrading=True,
         style=my_style)
