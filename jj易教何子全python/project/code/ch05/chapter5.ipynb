# %% [markdown]
# ### 5.2.1 使用urllib爬取静态网页数据

# %%
import urllib.request

url = 'https://example.com'
# 发送GET请求并获取响应
response = urllib.request.urlopen(url)
# 读取响应内容
data = response.read()
# 关闭响应
response.close()
# 处理数据
# ...

# %% [markdown]
# ### 5.2.2 实战9：爬取苹果股票数据

# %%
import urllib.request
# url = 'https://www.nasdaq.com/symbol/aapl/historical#.UWdnJBDMhHk'	
# 换成自己到路径
url = "file:///D:/书备份/2025/北大/《AI时代Python量化交易实战：DeepSeek让量化交易插上翅膀》/code/ch05/data/nasdaq-Apple1.html"

req = urllib.request.Request(url)

with urllib.request.urlopen(req) as response:
    data = response.read()
    html_data = data.decode()
    print(html_data)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="Generator" content="EditPlus®">
#     <meta name="Author" content="">
#     <meta name="Keywords" content="">
#     <meta name="Description" content="">
#     <title>Document</title>
# </head>
# <body>
# <div id="quotes_content_left_pnlAJAX">
#     <table class="historical-data__table">
#         <thead class="historical-data__table-headings">
#         <tr class="historical-data__row historical-data__row--headings">
#             <th class="historical-data__table-heading" scope="col">Date</th>
#             <th class="historical-data__table-heading" scope="col">Open</th>
#             <th class="historical-data__table-heading" scope="col">High</th>
#             <th class="historical-data__table-heading" scope="col">Low</th>
#             <th class="historical-data__table-heading" scope="col">Close</th>
#             <th class="historical-data__table-heading" scope="col">Volume</th>
# ...

# %% [markdown]
# ### 5.2.5 实战案例10：解析苹果股票数据

# %%
from bs4 import BeautifulSoup

sp = BeautifulSoup(html_data, 'html.parser')
# 返回<tbody>标签元素
tbody = sp.find('tbody')
# 返回<tbody>标签下所有的<tr>元素
trlist = tbody.select('tr')

data = []

for tr in trlist:
    fields = {}
    # 获得交易日期<th>元素
    th = tr.find('th')
    fields['Date'] = th.text  # 日期
    # 获得tr下的所有<td>元素
    tds = tr.select('td')
    fields['Open'] = tds[0].text  # 开盘
    fields['High'] = tds[1].text  # 最高
    fields['Low'] = tds[2].text  # 最低
    fields['Close'] = tds[3].text  # 收盘
    fields['Volume'] = tds[4].text  # 成交量

    data.append(fields)

print("解析完成。", data)
# Out:
# 解析完成。 [{'Date': '10/04/2022', 'Open': '225.64', 'High': '227.49', 'Low': '223.89', 'Close': '227.01', 'Volume': '34,755,550'}, {'Date': '10/03/2022', 'Open': '218.43', 'High': '220.96', 'Low': '215.132', 'Close': '220.82', 'Volume': '30,352,690'}, {'Date': '10/02/2022', 'Open': '223.06', 'High': '223.58', 'Low': '217.93', 'Close': '218.96', 'Volume': '35,767,260'}, {'Date': '10/01/2022', 'Open': '225.07', 'High': '228.22', 'Low': '224.2', 'Close': '224.59', 'Volume': '36,187,160'}, {'Date': '09/30/2022', 'Open': '220.9', 'High': '224.58', 'Low': '220.79', 'Close': '223.97', 'Volume': '26,318,580'}, {'Date': '09/27/2022', 'Open': '220.54', 'High': '220.96', 'Low': '217.2814', 'Close': '218.82', 'Volume': '25,361,290'}, {'Date': '09/26/2022', 'Open': '220', 'High': '220.94', 'Low': '218.83', 'Close': '219.89', 'Volume': '19,088,310'}, {'Date': '09/25/2022', 'Open': '218.55', 'High': '221.5', 'Low': '217.1402', 'Close': '221.03', 'Volume': '22,481,010'}, {'Date': '09/24/2022', 'Open': '
# ...

# %% [markdown]
# ### 保存数据CSV数据

# %%
import csv
keys = data[0].keys()

f = 'data/苹果股票数据.csv'
# 将数据写入CSV文件
with open(f, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=keys)

    # 写入表头
    writer.writeheader()

    # 写入数据
    writer.writerows(data)

print("CSV文件已生成：data.csv")
# Out:
# CSV文件已生成：data.csv

# %% [markdown]
# ### 5.2.7 实战案例11：使用Selenium爬取中石油股票数据

# %%
from selenium import webdriver	
from selenium.webdriver.common.by import By

driver = webdriver.Firefox()
driver.get('http://q.stock.sohu.com/cn/601857/lshq.shtml')
table_element = driver.find_element(By.ID, 'BIZ_hq_historySearch') 
print(table_element.text)
driver.quit()
# Out:
# 日期 开盘 收盘 涨跌额 涨跌幅 最低 最高 成交量(手) 成交金额(万) 换手率
# 累计： 2024-12-24至2025-04-24 -0.58 -6.76% 7.33 9.17 130685299 10658142.61 8.03%
# 2025-04-24 7.98 8.00 0.00 0.00% 7.97 8.03 641255 51349.35 0.04%
# 2025-04-23 8.06 8.00 -0.01 -0.12% 7.98 8.07 745146 59716.47 0.05%
# 2025-04-22 7.92 8.01 0.07 0.88% 7.91 8.05 1079581 86486.82 0.07%
# 2025-04-21 7.96 7.94 -0.05 -0.63% 7.92 8.01 804014 63978.59 0.05%
# 2025-04-18 8.00 7.99 0.00 0.00% 7.95 8.08 1071083 85749.02 0.07%
# 2025-04-17 7.97 7.99 0.01 0.13% 7.91 8.00 1022840 81451.10 0.06%
# 2025-04-16 7.73 7.98 0.23 2.97% 7.70 8.00 2156864 169079.66 0.13%
# 2025-04-15 7.68 7.75 0.06 0.78% 7.66 7.76 1336538 103093.09 0.08%
# 2025-04-14 7.56 7.69 0.13 1.72% 7.55 7.70 1697706 129624.38 0.10%
# 2025-04-11 7.56 7.56 -0.02 -0.26% 7.49 7.58 1474061 111126.74 0.09%
# 2025-04-10 7.64 7.58 0.04 0.53% 7.52 7.67 2508698 190098.55 0.15%
# 2025-04-09 7.60 7.54 -0.16 -2.08% 7.40 7.60 3461384 258923.44 0.21%
# ...

# %% [markdown]
# ### 5.2.8 实战案例12：使用Selenium解析HTML数据

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Firefox()
driver.get('http://q.stock.sohu.com/cn/601857/lshq.shtml')
table_element = driver.find_element(By.ID, 'BIZ_hq_historySearch')
tbody = table_element.find_element(By.TAG_NAME, "tbody")
trlist = tbody.find_elements(By.TAG_NAME, 'tr')

data = []

for idx, tr in enumerate(trlist):
    if idx == 0:
        # 跳过table第一行
        continue

    td_list = tr.find_elements(By.TAG_NAME, "td")
    fields = {}
    fields['Date'] = td_list[0].text  # 日期
    fields['Open'] = td_list[1].text  # 开盘
    fields['Close'] = td_list[2].text  # 收盘
    fields['Low'] = td_list[5].text  # 最低
    fields['High'] = td_list[6].text  # 最高
    fields['Volume'] = td_list[7].text  # 成交量
    data.append(fields)

print(data)
driver.quit()

# %% [markdown]
# ### 5.3.3 实战案例13：使用Tushare API获取中石油股票数据

# %%
# 导入tushare
import tushare as ts

# 初始化pro接口
pro = ts.pro_api('<修改为自己的TOKEN>')
df = pro.daily(ts_code='601857.SH', start_date='20240101', end_date='20250101')
df

# %% [markdown]
# #### 5.4.1 实战案例14：ABC股票数据清洗

# %%
import pandas as pd
# 读取数据文件
df = pd.read_csv('data/股票数据Test.csv')
# 处理前的数据
df

# %%
# 查找缺失值
missing_values = df.isnull().sum()	
print("缺失值数量：")
print(missing_values)

# %%
# 填充缺失值
# 使用平均值填充"收盘价"
mean_close = df['收盘价'].mean()
df['收盘价'].fillna(mean_close, inplace=True)

# 使用中位数填充"最低价"
median_low = df['最低价'].median()
df['最低价'].fillna(median_low, inplace=True)

# 使用邻近值填充"最高价"
df['最高价'].fillna(method='ffill', inplace=True)

# 使用0填充"成交量"
df['成交量'].fillna(0, inplace=True)

# 查看填充后的数据
print("处理后的数据：")
df

# %%
import pandas as pd
# 读取数据文件
df = pd.read_csv('data/股票数据Test.csv')

# 填充缺失值
# 使用平均值填充"收盘价"
mean_close = df['收盘价'].mean()
df['收盘价'].fillna(mean_close, inplace=True)

# 使用中位数填充"最低价"
median_low = df['最低价'].median()
df['最低价'].fillna(median_low, inplace=True)

# 使用邻近值填充"最高价"
df['最高价'].fillna(method='ffill', inplace=True)

# 使用0填充"成交量"
df['成交量'].fillna(0, inplace=True)


# 转换日期列的数据类型为字符串
df['日期'] = df['日期'].astype(str)

# 转换数值列的数据类型为浮点型
df['开盘价'] = df['开盘价'].astype(float)
df['收盘价'] = df['收盘价'].astype(float)
df['最低价'] = df['最低价'].astype(float)
df['最高价'] = df['最高价'].astype(float)
df['成交量'] = df['成交量'].astype(float)

# 查看处理后的数据
print("处理后的数据：")
df

# %% [markdown]
# ### 5.5.3 实战案例16：股票行业相关性分析

# %%
import pandas as pd
import numpy as np

# 从CSV文件读取数据
df = pd.read_csv('data/stock_data（相关性）.csv')  
# 转换日期列为日期类型
df['Date'] = pd.to_datetime(df['Date'])   
# 将日期列设为索引
df.set_index('Date', inplace=True)	
# 计算相关系数
correlation_matrix = np.corrcoef(df['Stock_A'], df['Stock_B'])
# 提取相关系数
correlation = correlation_matrix[0, 1]	
print('皮尔逊相关系数：', correlation)

# %% [markdown]
# ### 5.5.5 案实战例17：苹果股票数据统计描述和摘要分析

# %% [markdown]
# #### 1. 输出数据集的基本信息

# %%
import pandas as pd
# 读取股票数据
data = pd.read_csv('data/AAPL.csv', 
		converters={'Close': lambda x: float(x.replace('$', ''))}) 	
# 输出数据集的基本信息
data.info()

# %% [markdown]
# #### 2. 计算收盘价的统计特征

# %%
# 计算收盘价的统计特征
mean = data['Close'].mean()	
median = data['Close'].median()	
std = data['Close'].std()	
var = data['Close'].var()	
skew = data['Close'].skew()		
kurt = data['Close'].kurtosis()	
print('均值=%.2f,中位数=%.2f' % (mean, median))
print('标准差=%.2f,方差=%.2f' % (std, var))
print('偏度=%.2f,峰度=%.2f' % (skew, kurt))

# %% [markdown]
# #### 3.计算百分位数

# %%
# 计算百分位数
Q1 = data['Close'].quantile(0.25)
Q2 = data['Close'].quantile(0.5)	
Q3 = data['Close'].quantile(0.75)	
print('第一四分位数=%.2f,第二四分位数=%.2f,第三四分位数=%.2f' % (Q1, Q2, Q3))

# %% [markdown]
# #### 4. 价格趋势分析

# %%
# 价格趋势分析
# 计算涨跌天数和平均涨跌幅度
data['Return'] = data['Close'].pct_change()	
Up_days = len(data.loc[data['Return'] > 0])		
Down_days = len(data.loc[data['Return'] < 0])
Avg_Up = data.loc[data['Return'] > 0, 'Return'].mean()
Avg_Down = data.loc[data['Return'] < 0, 'Return'].mean()
print('涨%d天,平均上涨幅度为%0.2f%%' % (Up_days, Avg_Up*100))	
print('下跌%d天,平均下跌幅度为%0.2f%%' % (Down_days, Avg_Down*100))
