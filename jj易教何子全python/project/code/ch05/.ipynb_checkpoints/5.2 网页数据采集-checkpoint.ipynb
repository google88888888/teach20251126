# %% [markdown]
# ### 5.2.1 使用urllib爬取静态网页数据

# %%
import urllib.request

url = 'https://example.com'
# 发送GET请求并获取响应
response = urllib.request.urlopen(url)
# 读取响应内容
data = response.read()
# 关闭响应
response.close()
# 处理数据
# ...

# %% [markdown]
# ### 5.2.2 案例：爬取苹果股票数据

# %%
import urllib.request
# url = 'https://www.nasdaq.com/symbol/aapl/historical#.UWdnJBDMhHk'	
# 换成自己到路径
url = "file:///C:/Users/tonyg/OneDrive/书/北大/DeepSeek/《AI时代Python量化交易实战：DeepSeek让量化交易插上翅膀》/code/ch05/data/nasdaq-Apple1.html"

req = urllib.request.Request(url)

with urllib.request.urlopen(req) as response:
    data = response.read()
    html_data = data.decode()
    print(html_data)
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="Generator" content="EditPlus®">
#     <meta name="Author" content="">
#     <meta name="Keywords" content="">
#     <meta name="Description" content="">
#     <title>Document</title>
# </head>
# <body>
# <div id="quotes_content_left_pnlAJAX">
#     <table class="historical-data__table">
#         <thead class="historical-data__table-headings">
#         <tr class="historical-data__row historical-data__row--headings">
#             <th class="historical-data__table-heading" scope="col">Date</th>
#             <th class="historical-data__table-heading" scope="col">Open</th>
#             <th class="historical-data__table-heading" scope="col">High</th>
#             <th class="historical-data__table-heading" scope="col">Low</th>
#             <th class="historical-data__table-heading" scope="col">Close</th>
#             <th class="historical-data__table-heading" scope="col">Volume</th>
# ...

# %% [markdown]
# ### 5.2.5 案例：解析苹果股票数据

# %%
from bs4 import BeautifulSoup

sp = BeautifulSoup(html_data, 'html.parser')
# 返回<tbody>标签元素
tbody = sp.find('tbody')
# 返回<tbody>标签下所有的<tr>元素
trlist = tbody.select('tr')

data = []

for tr in trlist:
    fields = {}
    # 获得交易日期<th>元素
    th = tr.find('th')
    fields['Date'] = th.text  # 日期
    # 获得tr下的所有<td>元素
    tds = tr.select('td')
    fields['Open'] = tds[0].text  # 开盘
    fields['High'] = tds[1].text  # 最高
    fields['Low'] = tds[2].text  # 最低
    fields['Close'] = tds[3].text  # 收盘
    fields['Volume'] = tds[4].text  # 成交量

    data.append(fields)

print("解析完成。", data)
# Out:
# 解析完成。 [{'Date': '10/04/2022', 'Open': '225.64', 'High': '227.49', 'Low': '223.89', 'Close': '227.01', 'Volume': '34,755,550'}, {'Date': '10/03/2022', 'Open': '218.43', 'High': '220.96', 'Low': '215.132', 'Close': '220.82', 'Volume': '30,352,690'}, {'Date': '10/02/2022', 'Open': '223.06', 'High': '223.58', 'Low': '217.93', 'Close': '218.96', 'Volume': '35,767,260'}, {'Date': '10/01/2022', 'Open': '225.07', 'High': '228.22', 'Low': '224.2', 'Close': '224.59', 'Volume': '36,187,160'}, {'Date': '09/30/2022', 'Open': '220.9', 'High': '224.58', 'Low': '220.79', 'Close': '223.97', 'Volume': '26,318,580'}, {'Date': '09/27/2022', 'Open': '220.54', 'High': '220.96', 'Low': '217.2814', 'Close': '218.82', 'Volume': '25,361,290'}, {'Date': '09/26/2022', 'Open': '220', 'High': '220.94', 'Low': '218.83', 'Close': '219.89', 'Volume': '19,088,310'}, {'Date': '09/25/2022', 'Open': '218.55', 'High': '221.5', 'Low': '217.1402', 'Close': '221.03', 'Volume': '22,481,010'}, {'Date': '09/24/2022', 'Open': '
# ...

# %% [markdown]
# ### 保存数据CSV数据

# %%
import csv
keys = data[0].keys()

f = 'data/苹果股票数据.csv'
# 将数据写入CSV文件
with open(f, 'w', newline='') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=keys)

    # 写入表头
    writer.writeheader()

    # 写入数据
    writer.writerows(data)

print("CSV文件已生成：data.csv")

# %% [markdown]
# ### 5.2.8 案例：使用Selenium解析HTML数据

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Firefox()
driver.get('http://q.stock.sohu.com/cn/600519/lshq.shtml')
table_element = driver.find_element(By.ID, 'BIZ_hq_historySearch')
tbody = table_element.find_element(By.TAG_NAME, "tbody")
trlist = tbody.find_elements(By.TAG_NAME, 'tr')

data = []

for idx, tr in enumerate(trlist):
    if idx == 0:
        # 跳过table第一行
        continue

    td_list = tr.find_elements(By.TAG_NAME, "td")
    fields = {}
    fields['Date'] = td_list[0].text  # 日期
    fields['Open'] = td_list[1].text  # 开盘
    fields['Close'] = td_list[2].text  # 收盘
    fields['Low'] = td_list[5].text  # 最低
    fields['High'] = td_list[6].text  # 最高
    fields['Volume'] = td_list[7].text  # 成交量
    data.append(fields)

print(data)
driver.quit()
# Out:
# [{'Date': '2025-02-20', 'Open': '1483.00', 'Close': '1474.00', 'Low': '1473.39', 'High': '1491.97', 'Volume': '23750'}, {'Date': '2025-02-19', 'Open': '1475.05', 'Close': '1491.00', 'Low': '1464.90', 'High': '1494.44', 'Volume': '32393'}, {'Date': '2025-02-18', 'Open': '1470.00', 'Close': '1475.00', 'Low': '1462.08', 'High': '1492.99', 'Volume': '27800'}, {'Date': '2025-02-17', 'Open': '1481.00', 'Close': '1471.62', 'Low': '1467.10', 'High': '1494.98', 'Volume': '32471'}, {'Date': '2025-02-14', 'Open': '1465.06', 'Close': '1475.00', 'Low': '1458.22', 'High': '1477.00', 'Volume': '27100'}, {'Date': '2025-02-13', 'Open': '1443.02', 'Close': '1465.06', 'Low': '1434.51', 'High': '1475.25', 'Volume': '43385'}, {'Date': '2025-02-12', 'Open': '1418.00', 'Close': '1443.00', 'Low': '1416.88', 'High': '1445.00', 'Volume': '25476'}, {'Date': '2025-02-11', 'Open': '1434.95', 'Close': '1418.00', 'Low': '1415.90', 'High': '1435.96', 'Volume': '23573'}, {'Date': '2025-02-10', 'Open': '1438.00', 'Cl
# ...

# %% [markdown]
# ### 5.3.3 案例：使用Tushare API获取中石油股票数据

# %%
# 导入tushare
import tushare as ts

# 初始化pro接口
pro = ts.pro_api('<修改为自己的TOKEN>')
df = pro.daily(ts_code='600519.SH', start_date='20240101', end_date='20250101')
df
# Out:
#        ts_code trade_date     open     high      low    close  pre_close  \
# 0    600519.SH   20241231  1525.40  1545.00  1522.01  1524.00    1525.00
# 1    600519.SH   20241230  1533.97  1543.96  1525.00  1525.00    1528.97
# 2    600519.SH   20241227  1528.90  1536.00  1519.50  1528.97    1527.79
# 3    600519.SH   20241226  1534.00  1538.78  1523.00  1527.79    1530.00
# 4    600519.SH   20241225  1538.80  1538.80  1526.10  1530.00    1538.82
# ..         ...        ...      ...      ...      ...      ...        ...
# 237  600519.SH   20240108  1661.00  1662.00  1640.01  1643.99    1663.36
# 238  600519.SH   20240105  1661.33  1678.66  1652.11  1663.36    1669.00
# 239  600519.SH   20240104  1693.00  1693.00  1662.93  1669.00    1694.00
# 240  600519.SH   20240103  1681.11  1695.22  1676.33  1694.00    1685.01
# 241  600519.SH   20240102  1715.00  1718.19  1678.10  1685.01    1726.00
#
#      change  pct_chg       vol       amount
# 0     -1.00  -0.0656  39354.45  6033540.366
# ...
